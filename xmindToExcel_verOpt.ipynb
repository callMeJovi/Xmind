# %%
# final version
# get input file name
def get_input_file_name():
    return input("Enter the input file name (with extension .xmind): ").strip()

# %%
# get output file name
def get_output_file_name():
    return input("Enter the output file name (with extension .xlsx): ").strip()

# %%
import tkinter as tk
from tkinter import messagebox

# message box for folder creation will pop up to give the user instructions to follow
def warningbox_creat_folder():
    root=tk.Tk()
    root.withdraw()
    messagebox.showinfo("Folder being created", "Now, move your input files .xmind in the new folder before shuting down the warning box")
    root.destroy()

# %%
import tkinter as tk
from tkinter import messagebox

# message box for renaming the folder will pop up to give the user instructions to follow
def warningbox_rename_folder():
    root=tk.Tk()
    root.withdraw()
    messagebox.showinfo("Folder being renamed", "Now, make sure you have your input files .xmind in this folder before shuting down the warning box")
    root.destroy()

# %%
# function to create a folder
from pathlib import Path

def create_folder(base_path, folder_name):
    folder_path= Path(base_path)/folder_name
    if not folder_path.exists():
        folder_path.mkdir(parents=True)
        print(f"Folder created: {folder_path}")
        warningbox_creat_folder()
    else:
        print(f"Folder already exists: {folder_path}")
    return folder_path

# %%
# function to rename a folder

def rename_folder(base_path, old_name, new_name):
    old_path = Path(base_path) / old_name
    new_path = Path(base_path) / new_name
    
    if old_path.exists():
        old_path.rename(new_path)
        print(f"Folder renamed from {old_name} to {new_name}")
        warningbox_rename_folder()
        return new_path
    else:
        print(f"Folder '{old_name}' does not exist.")
        return None

# %%
# function to manage the input path
def main():
    home_dir = Path.home()  # ton home directory C/User/ton NNI
    subdir_path = home_dir / "OneDrive - EDF" / "Data_input_for_studies" / "xmind_tool"
    subdir_path.mkdir(parents=True, exist_ok=True)
    print(f"Using subdirectory path: {subdir_path}")

    # spécifier ou changer le nom du dossier
    action = input("Do you want to create or rename a folder? (create/rename/none): ").strip().lower()
    if action == "create":
        folder_name = input("Enter the name of the new folder: ").strip()
        folder_path = create_folder(subdir_path, folder_name)
    elif action == "rename":
        old_name = input("Enter the current folder name: ").strip()
        new_name = input("Enter the new folder name: ").strip()
        folder_path = rename_folder(subdir_path, old_name, new_name)
    else:
        folder_name = "DefaultFolder"
        folder_path = subdir_path / folder_name
        print(f"Using default folder path: {folder_path}")
        folder_path.mkdir(parents=True, exist_ok=True)

    # indiquer un nom à ton input fichier (xmind)
    input_file_name = get_input_file_name()
    input_file_path = folder_path / input_file_name

    print(f"Constructed file path: {input_file_path}")

    if not input_file_path.exists():
        with open(input_file_path, 'w') as file:
            file.write("")  # Create an empty file
        print(f"File created: {input_file_path}")
    else:
        print(f"File already exists: {input_file_path}")

    # indiquer un nom à ton output fichier (xlsx)
    output_file_name=get_output_file_name()
    output_file_path=folder_path / output_file_name

    print(f"Constructed file path: {output_file_path}")

    # if not output_file_path.exists():
    #     with open(output_file_path, 'w') as file:
    #         file.write("")
    #     print(f"Output file created: {output_file_path}")
    # else:
    #     print(f"Output file already exists: {output_file_path}")
    
    # parsed_data = xmind_to_dict(input_file_path)
    return input_file_path, output_file_path


if __name__ == "__main__":
    input_file_path, output_file_path = main()
    print(input_file_path, output_file_path)
# Out:
# Using subdirectory path: C:\Users\jl0331el\OneDrive - EDF\Data_input_for_studies\xmind_tool
# Folder created: C:\Users\jl0331el\OneDrive - EDF\Data_input_for_studies\xmind_tool\topla
# Constructed file path: C:\Users\jl0331el\OneDrive - EDF\Data_input_for_studies\xmind_tool\topla\SYNOPTIQUES Blénod TEST_Raja.xmind
# File already exists: C:\Users\jl0331el\OneDrive - EDF\Data_input_for_studies\xmind_tool\topla\SYNOPTIQUES Blénod TEST_Raja.xmind
# Constructed file path: C:\Users\jl0331el\OneDrive - EDF\Data_input_for_studies\xmind_tool\topla\exported_excel.xlsx
# C:\Users\jl0331el\OneDrive - EDF\Data_input_for_studies\xmind_tool\topla\SYNOPTIQUES Blénod TEST_Raja.xmind C:\Users\jl0331el\OneDrive - EDF\Data_input_for_studies\xmind_tool\topla\exported_excel.xlsx

# %%
# parser l'input file xmind
from xmindparser import xmind_to_dict
import pprint
# from pathlib import Path


# home_dir = Path.home()
# input_file = home_dir.joinpath("OneDrive - EDF", "XMind", input_file_name)
# output_file = home_dir.joinpath("OneDrive - EDF", "XMind", "output_excel", output_file_name)
parsed_data = xmind_to_dict(input_file_path)
pprint.pprint(parsed_data)
# Out:
# [{'id': '16u62jnfsfikhd5krul46pvkqq',
#   'structure': 'org.xmind.ui.map.unbalanced',
#   'title': 'Feuille  1',
#   'topic': {'comment': None,
#             'id': '6j8u9lt5si8o3pm1m3vuof8p5u',
#             'labels': None,
#             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/168',
#             'makers': None,
#             'note': None,
#             'title': 'MYPLANTONLINE BLENOD - SYNOPTIQUES ',
#             'topics': [{'comment': None,
#                         'id': '37k6r44ao9cnman2el5fievdfd',
#                         'labels': None,
#                         'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/173',
#                         'makers': None,
#                         'note': None,
#                         'title': 'prévision de fonctionnement'},
#                        {'comment': None,
#                         'id': '5fgdrt9cldckkb02ctbq39vtl5',
#                         'labels': None,
#                         'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/168',
#                         'makers': None,
#                         'note': None,
#                         'title': 'Etat macro de la tranche',
#                         'topics': [{'comment': None,
#                                     'id': '3205hvckns3jm6r5aeaggppa5o',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1635',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Arrêts / Démarrages'},
#                                    {'comment': None,
#                                     'id': '5pmdapkc8hnqk7plce6j06d24v',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1636',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Détails combustible'},
#                                    {'comment': None,
#                                     'id': '63ob76sf13qfmae2pn1q7jsoc1',
#                                     'labels': None,
#                                     'link': None,
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Prévision méteo',
#                                     'topics': [{'comment': None,
#                                                 'id': '54l6bpjiumt9isu1118ju964sp',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/581',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Blénod'},
#                                                {'comment': None,
#                                                 'id': '1vqvk67h8o28jd37nnavkn7em4',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/576',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Bouchain'},
#                                                {'comment': None,
#                                                 'id': '33q8ev2pluu3i5n5ne6fi14481',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/582',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Martigues'}]},
#                                    {'comment': None,
#                                     'id': '3uv8600kis786alncg8ej52qqj',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1537',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'historique programme',
#                                     'topics': [{'comment': None,
#                                                 'id': '1efdsifj7auoktjvhqhl9hntkj',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1632',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Accueil'},
#                                                {'comment': None,
#                                                 'id': '7jiu206mdpmfqrmc08mqtrnjp5',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/168',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Synoptiques'},
#                                                {'comment': None,
#                                                 'id': '15fstv98jobnnukp5rbvedam58',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1835',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Vue globale CCG'},
#                                                {'comment': None,
#                                                 'id': '18r0t197juiq2218v2j2lrtfs3',
#                                                 'labels': None,
#                                                 'link': None,
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Verification tags '
#                                                          'Optimus',
#                                                 'topics': [{'comment': None,
#                                                             'id': '6tg10ehs58t80c8hc45g9k185a',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1985',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Blénod'},
#                                                            {'comment': None,
#                                                             'id': '2r5obpj3c1egjshqsadcughbgv',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1990',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Bouchain'},
#                                                            {'comment': None,
#                                                             'id': '6usj78f8c9jkrr2coun094i06h',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1991',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Martigues'},
#                                                            {'comment': None,
#                                                             'id': '7vfbo27cuerlqff4r34vuknufu',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1992',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Cordemais'},
#                                                            {'comment': None,
#                                                             'id': '15ji4vm1hevmg8tp031bqvqb43',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/2011',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Arrighi'},
#                                                            {'comment': None,
#                                                             'id': '1rvr8pggnaj9hs8rc7vitbel80',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/2012',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Montereau'},
#                                                            {'comment': None,
#                                                             'id': '53no0n0l3nspn4r4337tfcd5nf',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1993',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Vaires'},
#                                                            {'comment': None,
#                                                             'id': '393bu9p4d0nq59omliq037gg05',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/2010',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Genneviliers'},
#                                                            {'comment': None,
#                                                             'id': '5runoak8bd38ln77ptv3or0gfg',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1994',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Brennilis'},
#                                                            {'comment': None,
#                                                             'id': '4osp5fn6j6u4bbqo8cbuskpbtf',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1995',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Dirinon'}]},
#                                                {'comment': None,
#                                                 'id': '68mpj79qp51s89na9q5vcsv2eh',
#                                                 'labels': None,
#                                                 'link': None,
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Prévision météo',
#                                                 'topics': [{'comment': None,
#                                                             'id': '0bi7mfcuqaj2mbo5mh6hniqrmp',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/581',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Blénod'},
#                                                            {'comment': None,
#                                                             'id': '4l9lp3349volbf3gui7l1aapm5',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/576',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Bouchain'},
#                                                            {'comment': None,
#                                                             'id': '5oi68vhtjjn40fujodhg2vtn36',
#                                                             'labels': None,
#                                                             'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/582',
#                                                             'makers': None,
#                                                             'note': None,
#                                                             'title': 'Martigues'}]}]},
#                                    {'comment': None,
#                                     'id': '73mo9nbm77kevre7t0kve9vvud',
#                                     'labels': None,
#                                     'link': None,
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'vérification tags optimus',
#                                     'topics': [{'comment': None,
#                                                 'id': '6ali09rs1ko2648bfd68g57vuq',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1985',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Blénod'},
#                                                {'comment': None,
#                                                 'id': '7699ulnprkjmdc7u7m11fqf8ti',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1990',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Bouchain'},
#                                                {'comment': None,
#                                                 'id': '10oksf7td9g9hhgrik8ej4c40v',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1991',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Martigues'},
#                                                {'comment': None,
#                                                 'id': '686vo3lisd3ocvvkos5o0rit92',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1992',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Cordemais'},
#                                                {'comment': None,
#                                                 'id': '6bfq59bcva5bc6265rdd15o324',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/2011',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Arrighi'},
#                                                {'comment': None,
#                                                 'id': '15piup9t72h71eg3dpt40p8o40',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/2012',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Montereau'},
#                                                {'comment': None,
#                                                 'id': '4km59ngumaslctark8tvi7bot0',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1993',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Vaires'},
#                                                {'comment': None,
#                                                 'id': '4ei4rjhdjm89t11eaon8g7c8vk',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/2010',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Genneviliers'},
#                                                {'comment': None,
#                                                 'id': '3kld363gp8f6go0dr6a8vtgh4k',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1994',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Brennilis'},
#                                                {'comment': None,
#                                                 'id': '066uc3hiblgqi9rj0vm0huh2a4',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1995',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Dirinon'}]},
#                                    {'comment': None,
#                                     'id': '0p8djnj9mh4c844ki6qt53udqt',
#                                     'labels': None,
#                                     'link': None,
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Conso gaz au démarrage',
#                                     'topics': [{'comment': None,
#                                                 'id': '489cnqtikvjiesf8g19l99k85f',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1691',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'BLENOD'},
#                                                {'comment': None,
#                                                 'id': '37n8juioned3kkv7okj7005rvh',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1706',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'BOUCHAIN'},
#                                                {'comment': None,
#                                                 'id': '3up1cjle1v2rilrhoq9fu51ub9',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1696',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'MARTI5'},
#                                                {'comment': None,
#                                                 'id': '7le17ibm85l7hqqdaf12fkl53o',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1707',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'MARTI6'}]}]},
#                        {'comment': None,
#                         'id': '2bdg8uqttk4sak25g69rou0jts',
#                         'labels': None,
#                         'link': None,
#                         'makers': None,
#                         'note': None,
#                         'title': 'Conduite',
#                         'topics': [{'comment': None,
#                                     'id': '4ccoams4cdl9irjqfu0mml7qo9',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/156',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Vue générale'},
#                                    {'comment': None,
#                                     'id': '5chkc0bd07eikq48ual7nc645i',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/161',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'GT',
#                                     'topics': [{'comment': None,
#                                                 'id': '5ep4la6rou2jrdk6945uaoq3e7',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1644',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Echappement'},
#                                                {'comment': None,
#                                                 'id': '07tofsl45o37juq18svongvf1n',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1667',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Pulsations '
#                                                          'combustion'},
#                                                {'comment': None,
#                                                 'id': '28ctglmp71ovm3h2c8njt6c0h1',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1679',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Temp inter-roues'},
#                                                {'comment': None,
#                                                 'id': '04iv642672c2eevospk9vune8e',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1165',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Vibrations TAC'},
#                                                {'comment': None,
#                                                 'id': '64b0mn18olmh3321ec1sbvp88b',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1665',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Temp '
#                                                          'palier&alternateur'},
#                                                {'comment': None,
#                                                 'id': '1tcajo9okmb805c231aaodb47u',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1682',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'IBH VS CTIM'},
#                                                {'comment': None,
#                                                 'id': '64u9c7411dhpe8ncrlu78mull7',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1694',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'CR VS CTIM'},
#                                                {'comment': None,
#                                                 'id': '01goq3ga0qb2qa3iu6o3dqb0bi',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1149',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'vannes anti-pompage'},
#                                                {'comment': None,
#                                                 'id': '73fmr32gtghfvi2kanbu830u37',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1150',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Vannes de purge '
#                                                          'gaz '},
#                                                {'comment': None,
#                                                 'id': '6juvr7shugrb6q7ukk3jcj6lgs',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1151',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Leak test'},
#                                                {'comment': None,
#                                                 'id': '79jq6ruglvc5jg93fspr50nc4f',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1852',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Compresseur : Actual '
#                                                          'VS Expected'}]},
#                                    {'comment': None,
#                                     'id': '4vbg4rtgfigiocgpsjn9d6e614',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/159?starttime=-8784h&endtime=*',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'HRSG',
#                                     'topics': [{'comment': None,
#                                                 'id': '5eapa3sfsv6o0c1aton2935idv',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1680',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Pompes alimentaires'},
#                                                {'comment': None,
#                                                 'id': '5jedb1or2226c73847dt5587i8',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1681',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'BYPASS'},
#                                                {'comment': None,
#                                                 'id': '20o4pcg2brjgaqc1os8lbvlm6l',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1814',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Suivi inétancheité '
#                                                          'Bypass HP'},
#                                                {'comment': None,
#                                                 'id': '6e4vug3jmv8sdo6t50g46qbpll',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/2040',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Equilibres '
#                                                          'ballons'}]},
#                                    {'comment': None,
#                                     'id': '7it611h3f0065dkvo2502uf3la',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/171',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'ST',
#                                     'topics': [{'comment': None,
#                                                 'id': '6fcavo95glv6vrore58cftqlib',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1159',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Pressions glissantes '
#                                                          'VS Débits'},
#                                                {'comment': None,
#                                                 'id': '6bmssjend132gl6671g35a4la9',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1544',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Vibrations & '
#                                                          'dilatations TAV '},
#                                                {'comment': None,
#                                                 'id': '45e4fremk8mp9uucp4se14d9f7',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1693',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'dilatations VS '
#                                                          'Température'},
#                                                {'comment': None,
#                                                 'id': '0662tsec13um8lsg3edad04k28',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/351',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Fuite Vap HP'},
#                                                {'comment': None,
#                                                 'id': '1mtoipe48foua7ves604trtkbd',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1666',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Temp paliers et '
#                                                          'alternateur'}]},
#                                    {'comment': None,
#                                     'id': '4gh0228nq0ivp1iqcsmelhkgjc',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/160',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Condenseur',
#                                     'topics': [{'comment': None,
#                                                 'id': '0pfc52f5orhkruhgugb7991epb',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1641',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'PCC'},
#                                                {'comment': None,
#                                                 'id': '4e18b2mqlofq5fjqv0jft65m03',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1640',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'PAC'},
#                                                {'comment': None,
#                                                 'id': '6s9h4tmb5j4773f9hulrb6cpgm',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1639',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'PGC'},
#                                                {'comment': None,
#                                                 'id': '6koj3dos9g5lm48g81ub2unvl1',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1637',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'LCA'},
#                                                {'comment': None,
#                                                 'id': '0ugnnr1tfm4l78ospvr5bk2g0c',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1924',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Impact pompe à vide '
#                                                          'sur le vide'},
#                                                {'comment': None,
#                                                 'id': '3e1pm3hf63mu7ph1n0s47q4ej3',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/2025',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': "Bilan d'eau"}]},
#                                    {'comment': None,
#                                     'id': '7mbgk0suhs1mnpuoo4bdl8cumm',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/157',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Système refroidissement',
#                                     'topics': [{'comment': None,
#                                                 'id': '0rr7v5cd14pa564l872cga8dlm',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1692',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Vibrations & '
#                                                          'températures '
#                                                          'ventilateurs '}]},
#                                    {'comment': None,
#                                     'id': '3a3tagc9lmc5gjj4ov4ukhri7i',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/347',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Chimie',
#                                     'topics': [{'comment': None,
#                                                 'id': '6dqek69pqanlm6hqeveo1adttj',
#                                                 'labels': None,
#                                                 'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/2013',
#                                                 'makers': None,
#                                                 'note': None,
#                                                 'title': 'Suivi volumes '
#                                                          'déminée'}]}]},
#                        {'comment': None,
#                         'id': '7pucsrlitbokmrc4mcoqo9o4i7',
#                         'labels': None,
#                         'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/172',
#                         'makers': None,
#                         'note': None,
#                         'title': 'Efficacité énergétqiue'},
#                        {'comment': None,
#                         'id': '1abnhv125okcrk15v0982mcprg',
#                         'labels': None,
#                         'link': None,
#                         'makers': None,
#                         'note': None,
#                         'title': 'DEVELOPPEMENTS',
#                         'topics': [{'comment': None,
#                                     'id': '0e8q90fr25dnktd4guc0tj2aig',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/139/Blenod---Overview',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Blénod - Overview'}]},
#                        {'comment': None,
#                         'id': '4q5pcosc6o7g3bj2rj82goi9kb',
#                         'labels': None,
#                         'link': None,
#                         'makers': None,
#                         'note': None,
#                         'title': 'ETUDES',
#                         'topics': [{'comment': None,
#                                     'id': '3bm14co1769tfloim4qhcvjnfi',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1177/LAC82--Debit-HP-VS-Intensit%C3%A9',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'LAC82 : Débit HP  VS Intensité'},
#                                    {'comment': None,
#                                     'id': '6ouc1o035fgt0outgsjdi75dm5',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1162/LAC82--recirculation',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'LAC 82 : Recirculation'},
#                                    {'comment': None,
#                                     'id': '6fo1iohuju7ik26c53clr1qeig',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1178/LAC82--pincement-temp%C3%A9ratures',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'LAC82 ; Pincement températures'},
#                                    {'comment': None,
#                                     'id': '7mpdg2v9p9vvuqsva6238t98pk',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1691/BLENOD_CONSO_GAZ_DEMARRAGE',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'Blénod conso gaz démarrage'},
#                                    {'comment': None,
#                                     'id': '094cbkekqlgevctm4itkkrq1i4',
#                                     'labels': None,
#                                     'link': 'https://prod-thaf-vision.edf.fr/PIVision/#/Displays/1175/LAC82--Intensite-VS-Debit-HP',
#                                     'makers': None,
#                                     'note': None,
#                                     'title': 'LAC82 : Intensité VS Débit '
#                                              'HP'}]}]}}]

# %%
import pandas as pd

df = parsed_data

def extract_hierarchy(topics, path=None):
    """
    Faire une extraction de manière hierarchique et récursive
    de données dans les topics sousjacents.
    
    Args:
        topics (liste): Liste de topics.
        path (liste): Liste pour maintenir le trajectoir hierarchique.
    
    Returns:
        une liste de lignes où chaque ligne d'excel contient les titres hierarchique
        et un link.

    """
    if path is None:
        path = [] # initialiser la liste

    rows = []
    for topic in topics:
        current_path = path + [topic.get('title', '')]  # update la liste de path avec le titre actuel
        # vérifier si l'hyperlink exists au niveau actuel (la ligne actuelle)
        if 'link' in topic:
            rows.append(current_path + [topic['link']])
        else:
            # ajouter une ligne dans l'excel avec la valeur nulle d'hyperlink si l'hyperlink n'exist pas dans le dict
            rows.append(current_path + [''])
        
        # Récursion dans les subtopics
        if 'topics' in topic:
            rows.extend(extract_hierarchy(topic['topics'], current_path))
    return rows

# Création du root topic de la donnée parsé
root_topic = [{'title': df[0]['topic']['title'], 'link': df[0]['topic'].get('link'), 'topics': df[0]['topic']['topics']}]

# Extraction des lignes dans l'hierachie du dataframe
rows = extract_hierarchy(root_topic)

# Déterminer le longeur (profondeur) du titre => (titre level)
max_depth = max(len(row) - 1 for row in rows)

# Normalize rows to have equal columns (titles and link)
normalized_rows = [row[:-1] + [''] * (max_depth - len(row) + 1) + [row[-1]] for row in rows]

# Create dynamic column names for titles based on the maximum depth
columns = [f'Title Level {i+1}' for i in range(max_depth)] + ['Link']
df = pd.DataFrame(normalized_rows, columns=columns)

# Export to Excel
excel_file_path = output_file_path
df.to_excel(excel_file_path, index=False)

print(f"Excel file saved to: {excel_file_path}")
# Out:
# Excel file saved to: C:\Users\jl0331el\OneDrive - EDF\Data_input_for_studies\xmind_tool\topla\exported_excel.xlsx
